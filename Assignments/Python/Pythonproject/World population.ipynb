# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # Read the data

# %%
wp=pd.read_csv(r'C:\Users\vismaya\Desktop\WorldPopulation.csv')

# %% [markdown]
# # view

# %%
wp
# Out:
#     Year  Population  ChangePerc  NetChange  Density       Urban  UrbanPerc
# 0   2020  7794798739        1.05   81330639       52  4378993944         56
# 1   2019  7713468100        1.08   82377060       52  4299438618         56
# 2   2018  7631091040        1.10   83232115       51  4219817318         55
# 3   2017  7547858925        1.12   83836876       51  4140188594         55
# 4   2016  7464022049        1.14   84224910       50  4060652683         54
# ..   ...         ...         ...        ...      ...         ...        ...
# 65  1955  2773019936        1.77   48173195       19   877008842         32
# 66  1954  2724846741        1.76   47237781       18   850179106         31
# 67  1953  2677608960        1.78   46747398       18   824289989         31
# 68  1952  2630861562        1.81   46827301       18   799282533         30
# 69  1951  2584034261        1.88   47603112       17   775067697         30
#
# [70 rows x 7 columns]

# %% [markdown]
# # Index

# %%
wp.index
# Out:
# RangeIndex(start=0, stop=70, step=1)

# %% [markdown]
# # Top 3 rows

# %%
wp.head(3)
# Out:
#    Year  Population  ChangePerc  NetChange  Density       Urban  UrbanPerc
# 0  2020  7794798739        1.05   81330639       52  4378993944         56
# 1  2019  7713468100        1.08   82377060       52  4299438618         56
# 2  2018  7631091040        1.10   83232115       51  4219817318         55

# %% [markdown]
# # Bottom 3 rows

# %%
wp.tail(3)
# Out:
#     Year  Population  ChangePerc  NetChange  Density      Urban  UrbanPerc
# 67  1953  2677608960        1.78   46747398       18  824289989         31
# 68  1952  2630861562        1.81   46827301       18  799282533         30
# 69  1951  2584034261        1.88   47603112       17  775067697         30

# %% [markdown]
# # To check how many rows & columns

# %%
wp.shape
# Out:
# (70, 7)

# %% [markdown]
# # To check the datatype of attributes

# %%
wp.dtypes
# Out:
# Year            int64
# Population      int64
# ChangePerc    float64
# NetChange       int64
# Density         int64
# Urban           int64
# UrbanPerc       int64
# dtype: object

# %% [markdown]
# # To print no: of dimensions

# %%
wp.ndim
# Out:
# 2

# %% [markdown]
# # To print size of the data

# %%
wp.size
# Out:
# 490

# %% [markdown]
# # To check wheather data type is empty or not

# %%
wp.empty
# Out:
# False

# %% [markdown]
# # Print the column names

# %%
wp.columns
# Out:
# Index(['Year', 'Population', 'ChangePerc', 'NetChange', 'Density', 'Urban',
#        'UrbanPerc'],
#       dtype='object')

# %% [markdown]
# # Print the information of dataset

# %%
wp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        70 non-null     int64
#  1   Population  70 non-null     int64
#  2   ChangePerc  70 non-null     float64
#  3   NetChange   70 non-null     int64
#  4   Density     70 non-null     int64
#  5   Urban       70 non-null     int64
#  6   UrbanPerc   70 non-null     int64
# dtypes: float64(1), int64(6)
# memory usage: 3.9 KB

# %% [markdown]
# # Print statistical information

# %%
wp.describe()
# Out:
#               Year    Population  ChangePerc     NetChange    Density  \
# count    70.000000  7.000000e+01   70.000000  7.000000e+01  70.000000
# mean   1985.500000  5.002010e+09    1.616429  7.511954e+07  33.557143
# std      20.351085  1.594877e+09    0.321288  1.256972e+07  10.723989
# min    1951.000000  2.584034e+09    1.050000  4.674740e+07  17.000000
# 25%    1968.250000  3.570120e+09    1.262500  7.314225e+07  24.000000
# 50%    1985.500000  4.915745e+09    1.770000  7.942852e+07  33.000000
# 75%    2002.750000  6.361332e+09    1.847500  8.356683e+07  42.750000
# max    2020.000000  7.794799e+09    2.090000  9.290386e+07  52.000000
#
#               Urban  UrbanPerc
# count  7.000000e+01  70.000000
# mean   2.226815e+09  42.200000
# std    1.070191e+09   7.447595
# min    7.750677e+08  30.000000
# 25%    1.294408e+09  36.000000
# 50%    2.035272e+09  41.500000
# 75%    3.054260e+09  48.000000
# max    4.378994e+09  56.000000

# %% [markdown]
# # Print all statistical information

# %%
wp.describe(include="all")
# Out:
#               Year    Population  ChangePerc     NetChange    Density  \
# count    70.000000  7.000000e+01   70.000000  7.000000e+01  70.000000
# mean   1985.500000  5.002010e+09    1.616429  7.511954e+07  33.557143
# std      20.351085  1.594877e+09    0.321288  1.256972e+07  10.723989
# min    1951.000000  2.584034e+09    1.050000  4.674740e+07  17.000000
# 25%    1968.250000  3.570120e+09    1.262500  7.314225e+07  24.000000
# 50%    1985.500000  4.915745e+09    1.770000  7.942852e+07  33.000000
# 75%    2002.750000  6.361332e+09    1.847500  8.356683e+07  42.750000
# max    2020.000000  7.794799e+09    2.090000  9.290386e+07  52.000000
#
#               Urban  UrbanPerc
# count  7.000000e+01  70.000000
# mean   2.226815e+09  42.200000
# std    1.070191e+09   7.447595
# min    7.750677e+08  30.000000
# 25%    1.294408e+09  36.000000
# 50%    2.035272e+09  41.500000
# 75%    3.054260e+09  48.000000
# max    4.378994e+09  56.000000

# %% [markdown]
# #  To check is there any missing data

# %%
wp.isna()
# Out:
#      Year  Population  ChangePerc  NetChange  Density  Urban  UrbanPerc
# 0   False       False       False      False    False  False      False
# 1   False       False       False      False    False  False      False
# 2   False       False       False      False    False  False      False
# 3   False       False       False      False    False  False      False
# 4   False       False       False      False    False  False      False
# ..    ...         ...         ...        ...      ...    ...        ...
# 65  False       False       False      False    False  False      False
# 66  False       False       False      False    False  False      False
# 67  False       False       False      False    False  False      False
# 68  False       False       False      False    False  False      False
# 69  False       False       False      False    False  False      False
#
# [70 rows x 7 columns]

# %% [markdown]
# # Sum of missing value

# %%
wp.isna().sum()
# Out:
# Year          0
# Population    0
# ChangePerc    0
# NetChange     0
# Density       0
# Urban         0
# UrbanPerc     0
# dtype: int64

# %%
wp
# Out:
#     Year  Population  ChangePerc  NetChange  Density       Urban  UrbanPerc
# 0   2020  7794798739        1.05   81330639       52  4378993944         56
# 1   2019  7713468100        1.08   82377060       52  4299438618         56
# 2   2018  7631091040        1.10   83232115       51  4219817318         55
# 3   2017  7547858925        1.12   83836876       51  4140188594         55
# 4   2016  7464022049        1.14   84224910       50  4060652683         54
# ..   ...         ...         ...        ...      ...         ...        ...
# 65  1955  2773019936        1.77   48173195       19   877008842         32
# 66  1954  2724846741        1.76   47237781       18   850179106         31
# 67  1953  2677608960        1.78   46747398       18   824289989         31
# 68  1952  2630861562        1.81   46827301       18   799282533         30
# 69  1951  2584034261        1.88   47603112       17   775067697         30
#
# [70 rows x 7 columns]

# %% [markdown]
# # Check the duplicated value

# %%
wp.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# Length: 70, dtype: bool

# %% [markdown]
# # sum of duplicated value

# %%
wp.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Number of unique values in dataset

# %%
wp.nunique()
# Out:
# Year          70
# Population    70
# ChangePerc    52
# NetChange     70
# Density       36
# Urban         70
# UrbanPerc     27
# dtype: int64

# %% [markdown]
# # Print unique number in the dataset of UrbanPerc

# %%
wp["UrbanPerc"].unique()
# Out:
# array([56, 55, 54, 53, 52, 51, 50, 49, 48, 47, 46, 45, 44, 43, 42, 41, 40,
#        39, 38, 37, 36, 35, 34, 33, 32, 31, 30], dtype=int64)

# %% [markdown]
# # print the count of Density in the dataset

# %%
wp["Density"].value_counts()
# Out:
# 19    3
# 20    3
# 22    3
# 18    3
# 35    2
# 43    2
# 37    2
# 39    2
# 40    2
# 41    2
# 42    2
# 46    2
# 44    2
# 47    2
# 48    2
# 50    2
# 51    2
# 36    2
# 52    2
# 27    2
# 24    2
# 21    2
# 32    2
# 23    2
# 30    2
# 29    2
# 28    2
# 33    2
# 26    2
# 25    2
# 49    1
# 34    1
# 45    1
# 31    1
# 38    1
# 17    1
# Name: Density, dtype: int64

# %% [markdown]
# # Show the maximum rates

# %%
wp.max()
# Out:
# Year          2.020000e+03
# Population    7.794799e+09
# ChangePerc    2.090000e+00
# NetChange     9.290386e+07
# Density       5.200000e+01
# Urban         4.378994e+09
# UrbanPerc     5.600000e+01
# dtype: float64

# %% [markdown]
# # Show the minimum rates

# %%
wp.min()
# Out:
# Year          1.951000e+03
# Population    2.584034e+09
# ChangePerc    1.050000e+00
# NetChange     4.674740e+07
# Density       1.700000e+01
# Urban         7.750677e+08
# UrbanPerc     3.000000e+01
# dtype: float64

# %%
wp.sort_values("Population",ascending=False).head(5)
# Out:
#    Year  Population  ChangePerc  NetChange  Density       Urban  UrbanPerc
# 0  2020  7794798739        1.05   81330639       52  4378993944         56
# 1  2019  7713468100        1.08   82377060       52  4299438618         56
# 2  2018  7631091040        1.10   83232115       51  4219817318         55
# 3  2017  7547858925        1.12   83836876       51  4140188594         55
# 4  2016  7464022049        1.14   84224910       50  4060652683         54

# %% [markdown]
# # To show the world population in rural urbanperc¶

# %%
rural = wp[["Density", "Year", "UrbanPerc"]]
rural
# Out:
#     Density  Year  UrbanPerc
# 0        52  2020         56
# 1        52  2019         56
# 2        51  2018         55
# 3        51  2017         55
# 4        50  2016         54
# ..      ...   ...        ...
# 65       19  1955         32
# 66       18  1954         31
# 67       18  1953         31
# 68       18  1952         30
# 69       17  1951         30
#
# [70 rows x 3 columns]

# %%
rural.sort_values("UrbanPerc").tail(10)
# Out:
#    Density  Year  UrbanPerc
# 9       47  2011         52
# 8       48  2012         53
# 7       48  2013         53
# 6       49  2014         53
# 5       50  2015         54
# 4       50  2016         54
# 3       51  2017         55
# 2       51  2018         55
# 1       52  2019         56
# 0       52  2020         56

# %% [markdown]
# # grouping total world populatin in year by UrbanPerc wise

# %%
wp.groupby('Year').agg({'UrbanPerc':'sum'})
# Out:
#       UrbanPerc
# Year
# 1951         30
# 1952         30
# 1953         31
# 1954         31
# 1955         32
# ...         ...
# 2016         54
# 2017         55
# 2018         55
# 2019         56
# 2020         56
#
# [70 rows x 1 columns]

# %% [markdown]
# # To print randon data

# %%
wp.sample(5)
# Out:
#     Year  Population  ChangePerc  NetChange  Density       Urban  UrbanPerc
# 23  1997  5905045788        1.38   80153837       40  2690813541         46
# 43  1977  4229506060        1.80   74839196       28  1616419308         38
# 37  1983  4699569304        1.78   82182762       32  1903822436         41
# 40  1980  4458003514        1.77   77497414       30  1754201029         39
# 68  1952  2630861562        1.81   46827301       18   799282533         30

# %% [markdown]
# # world population across 2020

# %%
wp.plot(kind='bar', figsize=(80,40))
plt.tick_params(axis='x', labelsize=33)
plt.tick_params(axis='y', labelsize=33)
plt.xlabel("Year", fontsize=40)
plt.ylabel("Density", fontsize=40)
plt.title(" population across 2020", fontsize=55)
plt.legend(["Urban", "UrbanPerc", "NetChange"],prop={"size":30})
plt.show()

# %% [markdown]
# # Seaborn

# %% [markdown]
# # Scatter plot

# %%
x = [50,51,52,53,54,55]
y = [30,31,32,33,34,35]
plt.scatter(x,y,label="Year", color='r', s=500)

plt.xlabel('Density')
plt.ylabel('UrbanPerc')
plt.title('Scatter plot')
plt.legend()
plt.show()

# %% [markdown]
# # Line Plot

# %%
sns.lineplot(x="Year", y="Density", hue="ChangePerc", data=wp)
plt.show()

# %% [markdown]
# # jitter

# %%
sns.set_style("darkgrid")
sns.stripplot(x="UrbanPerc",y="Density",jitter=0.20,data=wp)
plt.show()

# %% [markdown]
# # dodge

# %%
sns.set_style("darkgrid")
sns.stripplot(x="UrbanPerc", y="Density", jitter=0.20, dodge=True, data=wp)
plt.show()

# %% [markdown]
# # Rel plot

# %%
sns.scatterplot(x="UrbanPerc", y="Density", data=wp)""
plt.show()

# %% [markdown]
# # Cat plot

# %%
sns.scatterplot(x="UrbanPerc", y="Density", hue="ChangePerc", data=wp)
plt.show()

# %%
sns.catplot(x="UrbanPerc", y="Density", kind="point", data=wp)
plt.show()

# %% [markdown]
# # kdeplot of Density

# %%
sns.kdeplot(wp["Density"])
plt.show()

# %%
sns.kdeplot(wp["Density"], color="blue", shade=True)
plt.show()

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(wp)
plt.show()

# %%
sns.pairplot(wp,diag_kind="kde")
plt.show()

# %% [markdown]
# # violin plot

# %%
plt.figure(figsize=(16,18))
sns.violinplot(x="ChangePerc", y="Density", figsize=10, data=wp)
plt.show()

# %% [markdown]
# # swarm plot

# %%
sns.swarmplot(wp["Density"])
plt.show()

# %% [markdown]
# # swarm plot between ChangePerc & Density

# %%
plt.figure(figsize=(16,18))
sns.swarmplot(x="ChangePerc",y="Density", data=wp)
plt.show()

# %% [markdown]
# # Box plot of Density

# %%
sns.boxplot(wp['Density'])
plt.show()

# %%
sns.boxplot(y=wp["Density"])
plt.show()

# %% [markdown]
# # Heat Map

# %% [markdown]
# # correlation

# %%
wp.corr()
# Out:
#                 Year  Population  ChangePerc  NetChange   Density     Urban  \
# Year        1.000000    0.998403   -0.887211   0.797789  0.997915  0.987119
# Population  0.998403    1.000000   -0.907773   0.768659  0.999640  0.993085
# ChangePerc -0.887211   -0.907773    1.000000  -0.451671 -0.908100 -0.924174
# NetChange   0.797789    0.768659   -0.451671   1.000000  0.767797  0.706693
# Density     0.997915    0.999640   -0.908100   0.767797  1.000000  0.992816
# Urban       0.987119    0.993085   -0.924174   0.706693  0.992816  1.000000
# UrbanPerc   0.994349    0.995669   -0.899791   0.753161  0.995339  0.995454
#
#             UrbanPerc
# Year         0.994349
# Population   0.995669
# ChangePerc  -0.899791
# NetChange    0.753161
# Density      0.995339
# Urban        0.995454
# UrbanPerc    1.000000

# %%
sns.heatmap(wp.corr())
plt.show()

# %%
sns.heatmap(wp.corr(), cmap='RdBu',annot=True)
plt.show()

# %%
sns.heatmap(wp.corr(), cmap='RdBu',annot=True, fmt='.1f')
plt.show()

# %% [markdown]
# # Dist plot of Density

# %%
sns.distplot(wp.Density)
plt.show()

# %% [markdown]
# # Displot of Density

# %%
sns.displot(wp.Density)
plt.show()

# %% [markdown]
# # Dist plot of Density without histogram

# %%
sns.distplot(wp.Density, hist=False)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.distplot(wp.Density,
             bins=20,
             kde_kws={'lw':8, 'color':'xkcd:bluish green'},
             hist_kws={'alpha':0.3, 'color':'gray'}
            )
plt.xlabel('Density', fontsize=16, labelpad=15)
plt.yticks([])
plt.show()

# %% [markdown]
# # Data Vizualisation

# %% [markdown]
# # Pie Chart of World population

# %%
y = np.array([0,20,40,60,80,100])
l= ["Density", "Population", "ChangePerc", "NetChange", "Urban", "UrbanPerc"]
c = ['r', 'b', 'g', 'k']

plt.pie(y,labels=l, startangle=90, shadow=True, colors=c, explode=(0,0.5,0,0,0,0))
plt.legend(loc='lower right', title='World population')
plt.show()

# %% [markdown]
# # Bar graph of Density Vs ChangePerc

# %%
plt.figure(figsize=(10,5))
plt.bar(wp["Density"],wp["ChangePerc"])
plt.title("Density Vs ChangePerc",fontsize=2,color="red")
plt.xlabel("Density",fontsize=15)
plt.ylabel("ChangePerc",fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='UrbanPerc', data=wp, palette='tab10')
plt.show()

# %% [markdown]
# # Pie Chart of UrbanPerc

# %%
plt.figure(figsize=(10,10))
plt.title('UrbanPerc', fontsize=20)
wp['UrbanPerc'].value_counts().plot.pie(autopct='%1.1f%%, shadow=True')
plt.show()

# %%
wp.groupby('Density')[['ChangePerc','UrbanPerc']].sum().plot.bar(color=['red','green'], figsize=(8,5))
plt.ylabel('ChangePerc/UrbanPerc')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Density', data=wp, palette='rocket_r',order=wp['Density'].value_counts().index)
plt.xlabel('Density', fontsize=25)
plt.xticks(rotation=70)
plt.show()
