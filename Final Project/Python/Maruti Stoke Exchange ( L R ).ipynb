# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
maru=pd.read_csv(r'C:\Users\vismaya\Desktop\MARUTI.csv')

# %%
maru
# Out:
#             Date  Symbol Series  Prev Close     Open     High      Low  \
# 0     09-07-2003  MARUTI     EQ      125.00   164.90   170.40   155.00
# 1     10-07-2003  MARUTI     EQ      164.30   167.00   168.70   164.50
# 2     11-07-2003  MARUTI     EQ      167.00   167.75   174.85   166.25
# 3     14-07-2003  MARUTI     EQ      173.35   174.25   179.25   174.25
# 4     15-07-2003  MARUTI     EQ      177.95   200.00   200.00   173.00
# ...          ...     ...    ...         ...      ...      ...      ...
# 4422  26-04-2021  MARUTI     EQ     6676.10  6690.20  6789.00  6600.00
# 4423  27-04-2021  MARUTI     EQ     6638.90  6669.95  6709.00  6542.00
# 4424  28-04-2021  MARUTI     EQ     6568.75  6568.75  6650.00  6545.00
# 4425  29-04-2021  MARUTI     EQ     6573.80  6635.00  6647.45  6552.00
# 4426  30-04-2021  MARUTI     EQ     6565.65  6537.10  6559.60  6421.00
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...

# %% [markdown]
# # Index

# %%
maru.index
# Out:
# RangeIndex(start=0, stop=4427, step=1)

# %% [markdown]
# # Top 5 rows

# %%
maru.head()
# Out:
#          Date  Symbol Series  Prev Close    Open    High     Low   Last  \
# 0  09-07-2003  MARUTI     EQ      125.00  164.90  170.40  155.00  164.0
# 1  10-07-2003  MARUTI     EQ      164.30  167.00  168.70  164.50  167.0
# 2  11-07-2003  MARUTI     EQ      167.00  167.75  174.85  166.25  173.6
# 3  14-07-2003  MARUTI     EQ      173.35  174.25  179.25  174.25  178.6
# 4  15-07-2003  MARUTI     EQ      177.95  200.00  200.00  173.00  176.3
#
#     Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0  164.30  165.95  35164283  5.835530e+14     NaN           8537695.0
# 1  167.00  166.74  10464179  1.744820e+14     NaN           4363947.0
# 2  173.35  172.45  11740117  2.024620e+14     NaN           3014852.0
# 3  177.95  177.91   5982324  1.064310e+14     NaN           1949217.0
# 4  176.20  176.88   6173689  1.092000e+14     NaN           1307694.0
#
#    %Deliverble
# 0       0.2428
# 1       0.4170
# 2       0.2568
# 3       0.3258
# 4       0.2118

# %% [markdown]
# # Bottom 5 rows

# %%
maru.tail()
# Out:
#             Date  Symbol Series  Prev Close     Open     High     Low  \
# 4422  26-04-2021  MARUTI     EQ     6676.10  6690.20  6789.00  6600.0
# 4423  27-04-2021  MARUTI     EQ     6638.90  6669.95  6709.00  6542.0
# 4424  28-04-2021  MARUTI     EQ     6568.75  6568.75  6650.00  6545.0
# 4425  29-04-2021  MARUTI     EQ     6573.80  6635.00  6647.45  6552.0
# 4426  30-04-2021  MARUTI     EQ     6565.65  6537.10  6559.60  6421.0
#
#          Last    Close     VWAP   Volume      Turnover    Trades  \
# 4422  6645.00  6638.90  6678.34   937344  6.259900e+14   74474.0
# 4423  6552.00  6568.75  6620.68  1610651  1.066360e+15  130986.0
# 4424  6581.00  6573.80  6598.62  1406270  9.279440e+14  117843.0
# 4425  6562.00  6565.65  6580.77   757075  4.982140e+14   64393.0
# 4426  6438.35  6455.65  6500.51   849997  5.525420e+14   95248.0
#
#       Deliverable Volume  %Deliverble
# 4422            464999.0       0.4961
# 4423            588617.0       0.3655
# ...

# %% [markdown]
# # To check how many rows & columns

# %%
maru.shape            # 4427 rows and 15 columns are present inthis dataset
# Out:
# (4427, 15)

# %% [markdown]
# # To check the datatype of attributes

# %%
maru.dtypes
# Out:
# Date                   object
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                float64
# Deliverable Volume    float64
# %Deliverble           float64
# dtype: object

# %% [markdown]
# # Size of data set

# %%
maru.size
# Out:
# 66405

# %% [markdown]
# # To print no: of dimensions

# %%
maru.ndim
# Out:
# 2

# %% [markdown]
# # To check wheather data type is empty or not

# %%
maru.empty
# Out:
# False

# %% [markdown]
# # Print  the column names

# %%
maru.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %% [markdown]
# # Print the information of dataset

# %%
maru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4427 entries, 0 to 4426
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                4427 non-null   object
#  1   Symbol              4427 non-null   object
#  2   Series              4427 non-null   object
#  3   Prev Close          4427 non-null   float64
#  4   Open                4427 non-null   float64
#  5   High                4427 non-null   float64
#  6   Low                 4427 non-null   float64
#  7   Last                4427 non-null   float64
#  8   Close               4427 non-null   float64
#  9   VWAP                4427 non-null   float64
#  10  Volume              4427 non-null   int64
#  11  Turnover            4427 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4426 non-null   float64
#  14  %Deliverble         4426 non-null   float64
# ...

# %% [markdown]
# # Print statistical information

# %%
maru.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  4427.000000  4427.000000  4427.000000  4427.000000  4427.000000
# mean   2923.575085  2927.873074  2962.918432  2889.128066  2924.651604
# std    2740.532701  2745.541243  2769.986950  2715.403311  2740.438635
# min     125.000000   164.000000   168.700000   155.000000   164.000000
# 25%     822.525000   825.100000   840.000000   806.300000   823.025000
# 50%    1412.450000  1414.000000  1432.000000  1390.350000  1412.200000
# 75%    5097.350000  5100.000000  5192.050000  5006.025000  5104.500000
# max    9832.450000  9966.000000  9996.400000  9725.000000  9846.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  4427.000000  4427.000000  4.427000e+03  4.427000e+03    2456.000000
# mean   2925.005094  2926.480642  1.194661e+06  2.395307e+14   55428.511808
# std    2740.723734  2742.675329  1.637957e+06  2.935760e+14   44405.350898
# ...

# %% [markdown]
# # Print all statistical information

# %%
maru.describe(include="all")
# Out:
#               Date  Symbol Series   Prev Close         Open         High  \
# count         4427    4427   4427  4427.000000  4427.000000  4427.000000
# unique        4427       1      1          NaN          NaN          NaN
# top     03-11-2009  MARUTI     EQ          NaN          NaN          NaN
# freq             1    4427   4427          NaN          NaN          NaN
# mean           NaN     NaN    NaN  2923.575085  2927.873074  2962.918432
# std            NaN     NaN    NaN  2740.532701  2745.541243  2769.986950
# min            NaN     NaN    NaN   125.000000   164.000000   168.700000
# 25%            NaN     NaN    NaN   822.525000   825.100000   840.000000
# 50%            NaN     NaN    NaN  1412.450000  1414.000000  1432.000000
# 75%            NaN     NaN    NaN  5097.350000  5100.000000  5192.050000
# max            NaN     NaN    NaN  9832.450000  9966.000000  9996.400000
#
#                 Low         Last        Close         VWAP        Volume  \
# ...

# %% [markdown]
# # To check is there any missing data

# %%
maru.isna()
# Out:
#        Date  Symbol  Series  Prev Close   Open   High    Low   Last  Close  \
# 0     False   False   False       False  False  False  False  False  False
# 1     False   False   False       False  False  False  False  False  False
# 2     False   False   False       False  False  False  False  False  False
# 3     False   False   False       False  False  False  False  False  False
# 4     False   False   False       False  False  False  False  False  False
# ...     ...     ...     ...         ...    ...    ...    ...    ...    ...
# 4422  False   False   False       False  False  False  False  False  False
# 4423  False   False   False       False  False  False  False  False  False
# 4424  False   False   False       False  False  False  False  False  False
# 4425  False   False   False       False  False  False  False  False  False
# 4426  False   False   False       False  False  False  False  False  False
#
# ...

# %% [markdown]
# # Sum of missing value

# %%
maru.isna().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                1971
# Deliverable Volume       1
# %Deliverble              1
# dtype: int64

# %%
maru
# Out:
#             Date  Symbol Series  Prev Close     Open     High      Low  \
# 0     09-07-2003  MARUTI     EQ      125.00   164.90   170.40   155.00
# 1     10-07-2003  MARUTI     EQ      164.30   167.00   168.70   164.50
# 2     11-07-2003  MARUTI     EQ      167.00   167.75   174.85   166.25
# 3     14-07-2003  MARUTI     EQ      173.35   174.25   179.25   174.25
# 4     15-07-2003  MARUTI     EQ      177.95   200.00   200.00   173.00
# ...          ...     ...    ...         ...      ...      ...      ...
# 4422  26-04-2021  MARUTI     EQ     6676.10  6690.20  6789.00  6600.00
# 4423  27-04-2021  MARUTI     EQ     6638.90  6669.95  6709.00  6542.00
# 4424  28-04-2021  MARUTI     EQ     6568.75  6568.75  6650.00  6545.00
# 4425  29-04-2021  MARUTI     EQ     6573.80  6635.00  6647.45  6552.00
# 4426  30-04-2021  MARUTI     EQ     6565.65  6537.10  6559.60  6421.00
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...

# %% [markdown]
# # Check the duplicated value

# %%
maru.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4422    False
# 4423    False
# 4424    False
# 4425    False
# 4426    False
# Length: 4427, dtype: bool

# %% [markdown]
# # sum of duplicated value

# %%
maru.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Number of unique values in dataset

# %%
maru.nunique()
# Out:
# Date                  4427
# Symbol                   1
# Series                   1
# Prev Close            4296
# Open                  3404
# High                  3860
# Low                   3897
# Last                  3788
# Close                 4296
# VWAP                  4397
# Volume                4421
# Turnover              4411
# Trades                2418
# Deliverable Volume    4406
# %Deliverble           3132
# dtype: int64

# %% [markdown]
# # Print unique number of high rate of maruthi stock exchange

# %%
maru["High"].unique()
# Out:
# array([ 170.4 ,  168.7 ,  174.85, ..., 6650.  , 6647.45, 6559.6 ])

# %% [markdown]
# # print the count of category in the dataset

# %%
maru["Turnover"].value_counts()
# Out:
# 1.052980e+14    2
# 1.166100e+14    2
# 5.055650e+13    2
# 4.400840e+13    2
# 1.308220e+14    2
#                ..
# 4.607850e+14    1
# 5.928680e+13    1
# 5.487660e+14    1
# 4.218790e+13    1
# 1.821850e+14    1
# Name: Turnover, Length: 4411, dtype: int64

# %% [markdown]
# # Show the maximum rates

# %%
maru.max()
# Out:
# Date                          31-12-2020
# Symbol                            MARUTI
# Series                                EQ
# Prev Close                       9832.45
# Open                              9966.0
# High                              9996.4
# Low                               9725.0
# Last                              9846.0
# Close                            9832.45
# VWAP                             9850.96
# Volume                          35164283
# Turnover              4878990000000000.0
# Trades                          407715.0
# Deliverable Volume             8537695.0
# %Deliverble                          1.0
# dtype: object

# %% [markdown]
# # Show the minimum rates

# %%
maru.min()
# Out:
# Date                       01-01-2004
# Symbol                         MARUTI
# Series                             EQ
# Prev Close                      125.0
# Open                            164.0
# High                            168.7
# Low                             155.0
# Last                            164.0
# Close                           164.3
# VWAP                           165.06
# Volume                          22796
# Turnover              2131520000000.0
# Trades                         1096.0
# Deliverable Volume             4896.0
# %Deliverble                    0.0343
# dtype: object

# %% [markdown]
# # sorting the values of maruti stoke exchange turnover

# %%
maru.sort_values("Turnover",ascending=False).head()
# Out:
#             Date  Symbol Series  Prev Close    Open     High      Low    Last  \
# 3086  30-11-2015  MARUTI     EQ     4580.05  4586.0  4700.00  4492.10  4555.0
# 4027  20-09-2019  MARUTI     EQ     5971.75  6015.0  6949.80  5982.45  6601.0
# 4327  03-12-2020  MARUTI     EQ     7206.50  7250.0  7782.85  7249.60  7735.0
# 4366  29-01-2021  MARUTI     EQ     7588.50  7685.0  7685.00  7170.00  7222.0
# 4028  23-09-2019  MARUTI     EQ     6591.95  6676.1  7000.00  6676.10  6885.1
#
#         Close     VWAP    Volume      Turnover    Trades  Deliverable Volume  \
# 3086  4606.90  4616.86  10567769  4.878990e+15  220554.0           8238140.0
# 4027  6591.95  6513.47   4892962  3.187020e+15  407715.0           1251204.0
# 4327  7739.10  7574.14   3846792  2.913610e+15  296652.0           1018274.0
# 4366  7206.65  7377.31   3069968  2.264810e+15  281099.0           1065452.0
# 4028  6897.85  6891.10   3140286  2.164000e+15  282219.0           1292336.0
#
#       %Deliverble
# ...

# %% [markdown]
# # Sort basis of high share values

# %%
maru.sort_values(by="High",ascending=False)
# Out:
#             Date  Symbol Series  Prev Close    Open     High      Low    Last  \
# 3597  20-12-2017  MARUTI     EQ     9801.50  9966.0  9996.40  9700.25  9755.4
# 3744  24-07-2018  MARUTI     EQ     9701.00  9778.0  9929.00  9725.00  9842.0
# 3745  25-07-2018  MARUTI     EQ     9832.45  9853.0  9875.85  9701.00  9769.0
# 3596  19-12-2017  MARUTI     EQ     9309.10  9345.0  9858.00  9326.00  9846.0
# 3746  26-07-2018  MARUTI     EQ     9758.95  9819.8  9831.70  9361.00  9390.0
# ...          ...     ...    ...         ...     ...      ...      ...     ...
# 7     18-07-2003  MARUTI     EQ      172.20   165.0   171.90   160.00   167.4
# 0     09-07-2003  MARUTI     EQ      125.00   164.9   170.40   155.00   164.0
# 8     21-07-2003  MARUTI     EQ      167.40   169.0   169.40   163.05   164.0
# 9     22-07-2003  MARUTI     EQ      164.90   164.0   169.15   162.10   168.6
# 1     10-07-2003  MARUTI     EQ      164.30   167.0   168.70   164.50   167.0
#
# ...

# %% [markdown]
# # Sort value basis of Low Share values

# %%
maru.sort_values(by="Low",ascending=False)
# Out:
#             Date  Symbol Series  Prev Close    Open     High      Low    Last  \
# 3744  24-07-2018  MARUTI     EQ     9701.00  9778.0  9929.00  9725.00  9842.0
# 3745  25-07-2018  MARUTI     EQ     9832.45  9853.0  9875.85  9701.00  9769.0
# 3597  20-12-2017  MARUTI     EQ     9801.50  9966.0  9996.40  9700.25  9755.4
# 3603  29-12-2017  MARUTI     EQ     9629.20  9659.0  9769.00  9650.00  9735.3
# 3604  01-01-2018  MARUTI     EQ     9729.55  9749.0  9789.00  9629.80  9644.0
# ...          ...     ...    ...         ...     ...      ...      ...     ...
# 1     10-07-2003  MARUTI     EQ      164.30   167.0   168.70   164.50   167.0
# 8     21-07-2003  MARUTI     EQ      167.40   169.0   169.40   163.05   164.0
# 9     22-07-2003  MARUTI     EQ      164.90   164.0   169.15   162.10   168.6
# 7     18-07-2003  MARUTI     EQ      172.20   165.0   171.90   160.00   167.4
# 0     09-07-2003  MARUTI     EQ      125.00   164.9   170.40   155.00   164.0
#
# ...

# %% [markdown]
# # To print High share value row set

# %%
a = maru["High"].max()
a
# Out:
# 9996.4

# %%
maru_max = maru.loc[(maru['High']==a)]
maru_max
# Out:
#             Date  Symbol Series  Prev Close    Open    High      Low    Last  \
# 3597  20-12-2017  MARUTI     EQ      9801.5  9966.0  9996.4  9700.25  9755.4
#
#        Close     VWAP   Volume      Turnover    Trades  Deliverable Volume  \
# 3597  9733.9  9848.56  1216280  1.197860e+15  127449.0            325474.0
#
#       %Deliverble
# 3597       0.2676

# %% [markdown]
# # To print mean, median, mode of data set

# %%
maru.mean()
# Out:
# Prev Close            2.923575e+03
# Open                  2.927873e+03
# High                  2.962918e+03
# Low                   2.889128e+03
# Last                  2.924652e+03
# Close                 2.925005e+03
# VWAP                  2.926481e+03
# Volume                1.194661e+06
# Turnover              2.395307e+14
# Trades                5.542851e+04
# Deliverable Volume    3.627677e+05
# %Deliverble           3.873908e-01
# dtype: float64

# %%
maru.mode()
# Out:
#             Date  Symbol Series  Prev Close   Open   High    Low   Last  \
# 0     01-01-2004  MARUTI     EQ      418.95  765.0  954.0  825.0  800.0
# 1     01-01-2008     NaN    NaN         NaN    NaN    NaN  920.0    NaN
# 2     01-01-2009     NaN    NaN         NaN    NaN    NaN    NaN    NaN
# 3     01-01-2013     NaN    NaN         NaN    NaN    NaN    NaN    NaN
# 4     01-01-2014     NaN    NaN         NaN    NaN    NaN    NaN    NaN
# ...          ...     ...    ...         ...    ...    ...    ...    ...
# 4422  31-12-2014     NaN    NaN         NaN    NaN    NaN    NaN    NaN
# 4423  31-12-2015     NaN    NaN         NaN    NaN    NaN    NaN    NaN
# 4424  31-12-2018     NaN    NaN         NaN    NaN    NaN    NaN    NaN
# 4425  31-12-2019     NaN    NaN         NaN    NaN    NaN    NaN    NaN
# 4426  31-12-2020     NaN    NaN         NaN    NaN    NaN    NaN    NaN
#
#        Close    VWAP    Volume      Turnover   Trades  Deliverable Volume  \
# ...

# %%
maru.median()
# Out:
# Prev Close            1.412450e+03
# Open                  1.414000e+03
# High                  1.432000e+03
# Low                   1.390350e+03
# Last                  1.412200e+03
# Close                 1.412600e+03
# VWAP                  1.412210e+03
# Volume                6.909590e+05
# Turnover              1.121590e+14
# Trades                4.403150e+04
# Deliverable Volume    2.717160e+05
# %Deliverble           3.899000e-01
# dtype: float64

# %% [markdown]
# # To print information of data set

# %%
maru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4427 entries, 0 to 4426
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                4427 non-null   object
#  1   Symbol              4427 non-null   object
#  2   Series              4427 non-null   object
#  3   Prev Close          4427 non-null   float64
#  4   Open                4427 non-null   float64
#  5   High                4427 non-null   float64
#  6   Low                 4427 non-null   float64
#  7   Last                4427 non-null   float64
#  8   Close               4427 non-null   float64
#  9   VWAP                4427 non-null   float64
#  10  Volume              4427 non-null   int64
#  11  Turnover            4427 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4426 non-null   float64
#  14  %Deliverble         4426 non-null   float64
# ...

# %% [markdown]
# # To print index values

# %%
maru.index
# Out:
# RangeIndex(start=0, stop=4427, step=1)

# %% [markdown]
# # Check relationship between data set

# %%
maru.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.999940  0.999819  0.999789  0.999665
# Open                  0.999940  1.000000  0.999842  0.999847  0.999696
# High                  0.999819  0.999842  1.000000  0.999771  0.999876
# Low                   0.999789  0.999847  0.999771  1.000000  0.999837
# Last                  0.999665  0.999696  0.999876  0.999837  1.000000
# Close                 0.999677  0.999709  0.999884  0.999849  0.999995
# VWAP                  0.999820  0.999856  0.999940  0.999920  0.999943
# Volume               -0.245643 -0.245440 -0.243687 -0.246699 -0.245025
# Turnover              0.649851  0.649903  0.655949  0.646019  0.651449
# Trades                0.464892  0.464263  0.474093  0.456209  0.465550
# Deliverable Volume   -0.194373 -0.194295 -0.191977 -0.196509 -0.194335
# %Deliverble           0.060529  0.060458  0.058686  0.060714  0.059028
#
# ...

# %% [markdown]
# # Filter date column

# %%
maru.filter(["Date"])
# Out:
#             Date
# 0     09-07-2003
# 1     10-07-2003
# 2     11-07-2003
# 3     14-07-2003
# 4     15-07-2003
# ...          ...
# 4422  26-04-2021
# 4423  27-04-2021
# 4424  28-04-2021
# 4425  29-04-2021
# 4426  30-04-2021
#
# [4427 rows x 1 columns]

# %%
year = maru.filter(["Date"])
year
# Out:
#             Date
# 0     09-07-2003
# 1     10-07-2003
# 2     11-07-2003
# 3     14-07-2003
# 4     15-07-2003
# ...          ...
# 4422  26-04-2021
# 4423  27-04-2021
# 4424  28-04-2021
# 4425  29-04-2021
# 4426  30-04-2021
#
# [4427 rows x 1 columns]

# %% [markdown]
# # To show Years from date column

# %%
pd.DatetimeIndex(year['Date']).year
# Out:
# Int64Index([2003, 2003, 2003, 2003, 2003, 2003, 2003, 2003, 2003, 2003,
#             ...
#             2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021],
#            dtype='int64', name='Date', length=4427)

# %% [markdown]
# # Add Year Column to data set

# %%
maru["Year"] = pd.DatetimeIndex(year['Date']).year
maru
# Out:
#             Date  Symbol Series  Prev Close     Open     High      Low  \
# 0     09-07-2003  MARUTI     EQ      125.00   164.90   170.40   155.00
# 1     10-07-2003  MARUTI     EQ      164.30   167.00   168.70   164.50
# 2     11-07-2003  MARUTI     EQ      167.00   167.75   174.85   166.25
# 3     14-07-2003  MARUTI     EQ      173.35   174.25   179.25   174.25
# 4     15-07-2003  MARUTI     EQ      177.95   200.00   200.00   173.00
# ...          ...     ...    ...         ...      ...      ...      ...
# 4422  26-04-2021  MARUTI     EQ     6676.10  6690.20  6789.00  6600.00
# 4423  27-04-2021  MARUTI     EQ     6638.90  6669.95  6709.00  6542.00
# 4424  28-04-2021  MARUTI     EQ     6568.75  6568.75  6650.00  6545.00
# 4425  29-04-2021  MARUTI     EQ     6573.80  6635.00  6647.45  6552.00
# 4426  30-04-2021  MARUTI     EQ     6565.65  6537.10  6559.60  6421.00
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...

# %% [markdown]
# # To add a column of Month for printing particular month from date column

# %%
pd.DatetimeIndex(year['Date']).month
# Out:
# Int64Index([ 9, 10, 11,  7,  7,  7,  7,  7,  7,  7,
#             ...
#              4,  4,  4,  4,  4,  4,  4,  4,  4,  4],
#            dtype='int64', name='Date', length=4427)

# %%
maru["Month"]  = pd.DatetimeIndex(year['Date']).month
maru
# Out:
#             Date  Symbol Series  Prev Close     Open     High      Low  \
# 0     09-07-2003  MARUTI     EQ      125.00   164.90   170.40   155.00
# 1     10-07-2003  MARUTI     EQ      164.30   167.00   168.70   164.50
# 2     11-07-2003  MARUTI     EQ      167.00   167.75   174.85   166.25
# 3     14-07-2003  MARUTI     EQ      173.35   174.25   179.25   174.25
# 4     15-07-2003  MARUTI     EQ      177.95   200.00   200.00   173.00
# ...          ...     ...    ...         ...      ...      ...      ...
# 4422  26-04-2021  MARUTI     EQ     6676.10  6690.20  6789.00  6600.00
# 4423  27-04-2021  MARUTI     EQ     6638.90  6669.95  6709.00  6542.00
# 4424  28-04-2021  MARUTI     EQ     6568.75  6568.75  6650.00  6545.00
# 4425  29-04-2021  MARUTI     EQ     6573.80  6635.00  6647.45  6552.00
# 4426  30-04-2021  MARUTI     EQ     6565.65  6537.10  6559.60  6421.00
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...

# %% [markdown]
# # To print column names

# %%
maru.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble', 'Year', 'Month'],
#       dtype='object')

# %% [markdown]
# # Extract data basis  Year 2021

# %%
maru_Year_2021 = maru.loc[(maru["Year"]== 2021 )]
maru_Year_2021
# Out:
#             Date  Symbol Series  Prev Close     Open     High     Low  \
# 4347  01-01-2021  MARUTI     EQ     7649.60  7654.00  7748.50  7650.0
# 4348  04-01-2021  MARUTI     EQ     7691.30  7739.00  7755.20  7642.6
# 4349  05-01-2021  MARUTI     EQ     7702.30  7660.00  7673.00  7586.0
# 4350  06-01-2021  MARUTI     EQ     7655.45  7654.00  7749.00  7555.5
# 4351  07-01-2021  MARUTI     EQ     7628.60  7676.00  7704.40  7552.1
# ...          ...     ...    ...         ...      ...      ...     ...
# 4422  26-04-2021  MARUTI     EQ     6676.10  6690.20  6789.00  6600.0
# 4423  27-04-2021  MARUTI     EQ     6638.90  6669.95  6709.00  6542.0
# 4424  28-04-2021  MARUTI     EQ     6568.75  6568.75  6650.00  6545.0
# 4425  29-04-2021  MARUTI     EQ     6573.80  6635.00  6647.45  6552.0
# 4426  30-04-2021  MARUTI     EQ     6565.65  6537.10  6559.60  6421.0
#
#          Last    Close     VWAP   Volume      Turnover    Trades  \
# ...

# %% [markdown]
# # Check and drop a row of Deliverable row as NAN

# %%
maru[maru['Deliverable Volume'].isna()]
# Out:
#           Date  Symbol Series  Prev Close   Open   High    Low   Last   Close  \
# 76  25-10-2003  MARUTI     EQ       285.0  294.9  297.7  291.5  293.6  293.75
#
#       VWAP   Volume      Turnover  Trades  Deliverable Volume  %Deliverble  \
# 76  294.51  1888755  5.562560e+13     NaN                 NaN          NaN
#
#     Year  Month
# 76  2003     10

# %%
maru.drop(76,axis=0,inplace=True)

# %%
maru.isna().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                1970
# Deliverable Volume       0
# %Deliverble              0
# Year                     0
# Month                    0
# dtype: int64

# %% [markdown]
# # Visualization

# %% [markdown]
# # To plot bar plot of percentage of delivery rates

# %%
plt.bar(maru['Year'],maru['%Deliverble'])
plt.title('Year Vs %Deliverble',fontsize=15,color='red')
plt.xlabel('Year',fontsize=15)
plt.ylabel('%Deliverble',fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# # Year wise analysis of high and low  share analysis

# %%
maru.groupby('Year')[['High','Low']].sum().plot.bar(color=['green','Yellow'],figsize=(10,10))
plt.title("Year wise Share Values",color="Green",fontsize=25)
plt.ylabel('Share Values',fontsize=15,color="blue")
plt.xlabel('Year',fontsize=15,color='blue')
plt.show()

# %% [markdown]
# # To show High share values in 2021

# %%
plt.barh(maru_Year_2021['Month'],maru_Year_2021['High'],color = 'green')
plt.title('Month Vs High',fontsize=20,color='red')
plt.xlabel('High',fontsize=15,color ='black')
plt.ylabel('Month',fontsize=15, color = 'orange')
plt.grid(True)
plt.show()

# %% [markdown]
# # Month basis of Analysis in year 2021

# %%
sns.countplot(x="Month",data=maru_Year_2021,palette='tab10')
plt.show()

# %% [markdown]
# # relational plot of highest & lowest maruti stock details

# %% [markdown]
# ### rel plot is a figure-level function for visualizing statistical relationship using  two common approaches.
#
# conclusion : it combines a FaceGrid with highest & lowest stoke details

# %%
plt.figure(figsize=(16,18))
sns.relplot(x='High', y='Low', data=maru)
plt.show()

# %% [markdown]
# # seaborn
#
# It is used to make statistical graphics.Seaborn helps in exploration and understanding of data

# %% [markdown]
# # To plot a line plot basis High share values in different year

# %%
sns.lineplot(x="Year",y="High",hue="Month",data=maru)
plt.show()

# %% [markdown]
# # Show a relationship plot in year 2021
#
# This helps to plot multiple pairwise bivariate distributions in a dataset
# Helps to find the relationship of each columns present in the dataset as a matrix of plots and the diaonal plots are the univariate plots.

# %%
sns.pairplot(maru_Year_2021)
plt.show()

# %% [markdown]
# # High share value shows using a violinplot
#
# Used to visualize data distributions, displaying the range,median, and distribution of the data.
# It is same statistics summary as boxplot , but they also include Kernal Density Estimations that represents the shape/distribution of the data.

# %%
sns.violinplot(x=maru.High,color='yellow')
plt.show()

# %% [markdown]
# # To plot a heat map
#
# * heat map is used to represent color-coding different values.
# * heatmap is a two-dimensional graphical representation od data where the individual values that are contained in a matrix are   represented as colors.

# %%
sns.heatmap(maru.corr(),cmap='RdBu',annot=True,fmt='.1f') 
plt.show()

# %% [markdown]
# # Machine learning

# %% [markdown]
# # To show a relationship of High value basis of Year

# %%
sns.scatterplot(y=maru['Year'],x=maru["High"],color='red')
plt.title("RELATIONAL PLOT",size=20,color='blue')
plt.ylabel("Year",size=15,color='green')
plt.xlabel("High values",size=15,color='green')
plt.show()

# %% [markdown]
# # To plot a relationship of VWAP basis of Year

# %%
sns.scatterplot(y=maru['Year'],x=maru["VWAP"],color='gold')  # Volume weighted average price
plt.title("RELATIONAL PLOT",size=20,color='green')
plt.ylabel("Year",size=15,color='red')
plt.xlabel("VWAP",size=15,color='red')
plt.show()

# %%
# print data set

maru
# Out:
#             Date  Symbol Series  Prev Close     Open     High      Low  \
# 0     09-07-2003  MARUTI     EQ      125.00   164.90   170.40   155.00
# 1     10-07-2003  MARUTI     EQ      164.30   167.00   168.70   164.50
# 2     11-07-2003  MARUTI     EQ      167.00   167.75   174.85   166.25
# 3     14-07-2003  MARUTI     EQ      173.35   174.25   179.25   174.25
# 4     15-07-2003  MARUTI     EQ      177.95   200.00   200.00   173.00
# ...          ...     ...    ...         ...      ...      ...      ...
# 4422  26-04-2021  MARUTI     EQ     6676.10  6690.20  6789.00  6600.00
# 4423  27-04-2021  MARUTI     EQ     6638.90  6669.95  6709.00  6542.00
# 4424  28-04-2021  MARUTI     EQ     6568.75  6568.75  6650.00  6545.00
# 4425  29-04-2021  MARUTI     EQ     6573.80  6635.00  6647.45  6552.00
# 4426  30-04-2021  MARUTI     EQ     6565.65  6537.10  6559.60  6421.00
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...

# %% [markdown]
# # Drop Date column

# %%
maru=maru.drop(['Date'],axis=1)

# %%
maru
# Out:
#       Symbol Series  Prev Close     Open     High      Low     Last    Close  \
# 0     MARUTI     EQ      125.00   164.90   170.40   155.00   164.00   164.30
# 1     MARUTI     EQ      164.30   167.00   168.70   164.50   167.00   167.00
# 2     MARUTI     EQ      167.00   167.75   174.85   166.25   173.60   173.35
# 3     MARUTI     EQ      173.35   174.25   179.25   174.25   178.60   177.95
# 4     MARUTI     EQ      177.95   200.00   200.00   173.00   176.30   176.20
# ...      ...    ...         ...      ...      ...      ...      ...      ...
# 4422  MARUTI     EQ     6676.10  6690.20  6789.00  6600.00  6645.00  6638.90
# 4423  MARUTI     EQ     6638.90  6669.95  6709.00  6542.00  6552.00  6568.75
# 4424  MARUTI     EQ     6568.75  6568.75  6650.00  6545.00  6581.00  6573.80
# 4425  MARUTI     EQ     6573.80  6635.00  6647.45  6552.00  6562.00  6565.65
# 4426  MARUTI     EQ     6565.65  6537.10  6559.60  6421.00  6438.35  6455.65
#
# ...

# %% [markdown]
# # To define x as dependent & y as independent variable

# %%
x = maru[[ 'Prev Close', 'Open', 'High', 'Low', 'Last',
       'Close', 'Volume','Trades', 'Deliverable Volume','Turnover',
       '%Deliverble']]

y = maru[[ 'VWAP','Year','Month']]

# %%
x
# Out:
#       Prev Close     Open     High      Low     Last    Close    Volume  \
# 0         125.00   164.90   170.40   155.00   164.00   164.30  35164283
# 1         164.30   167.00   168.70   164.50   167.00   167.00  10464179
# 2         167.00   167.75   174.85   166.25   173.60   173.35  11740117
# 3         173.35   174.25   179.25   174.25   178.60   177.95   5982324
# 4         177.95   200.00   200.00   173.00   176.30   176.20   6173689
# ...          ...      ...      ...      ...      ...      ...       ...
# 4422     6676.10  6690.20  6789.00  6600.00  6645.00  6638.90    937344
# 4423     6638.90  6669.95  6709.00  6542.00  6552.00  6568.75   1610651
# 4424     6568.75  6568.75  6650.00  6545.00  6581.00  6573.80   1406270
# 4425     6573.80  6635.00  6647.45  6552.00  6562.00  6565.65    757075
# 4426     6565.65  6537.10  6559.60  6421.00  6438.35  6455.65    849997
#
#         Trades  Deliverable Volume      Turnover  %Deliverble
# ...

# %%
y
# Out:
#          VWAP  Year  Month
# 0      165.95  2003      9
# 1      166.74  2003     10
# 2      172.45  2003     11
# 3      177.91  2003      7
# 4      176.88  2003      7
# ...       ...   ...    ...
# 4422  6678.34  2021      4
# 4423  6620.68  2021      4
# 4424  6598.62  2021      4
# 4425  6580.77  2021      4
# 4426  6500.51  2021      4
#
# [4426 rows x 3 columns]

# %% [markdown]
# # To check null values

# %%
x.isna()
# Out:
#       Prev Close   Open   High    Low   Last  Close  Volume  Trades  \
# 0          False  False  False  False  False  False   False    True
# 1          False  False  False  False  False  False   False    True
# 2          False  False  False  False  False  False   False    True
# 3          False  False  False  False  False  False   False    True
# 4          False  False  False  False  False  False   False    True
# ...          ...    ...    ...    ...    ...    ...     ...     ...
# 4422       False  False  False  False  False  False   False   False
# 4423       False  False  False  False  False  False   False   False
# 4424       False  False  False  False  False  False   False   False
# 4425       False  False  False  False  False  False   False   False
# 4426       False  False  False  False  False  False   False   False
#
#       Deliverable Volume  Turnover  %Deliverble
# 0                  False     False        False
# 1                  False     False        False
# ...

# %% [markdown]
# # sum of null values

# %%
x.isna().sum()
# Out:
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# Volume                   0
# Trades                1970
# Deliverable Volume       0
# Turnover                 0
# %Deliverble              0
# dtype: int64

# %% [markdown]
# # To print Highest stoke  column data

# %%
x['Trades']
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 4422     74474.0
# 4423    130986.0
# 4424    117843.0
# 4425     64393.0
# 4426     95248.0
# Name: Trades, Length: 4426, dtype: float64

# %% [markdown]
# # Fill Nill column of high with a value

# %%
x['Trades'].fillna(4320,inplace=True)

# %%
x['Trades']
# Out:
# 0         4320.0
# 1         4320.0
# 2         4320.0
# 3         4320.0
# 4         4320.0
#           ...
# 4422     74474.0
# 4423    130986.0
# 4424    117843.0
# 4425     64393.0
# 4426     95248.0
# Name: Trades, Length: 4426, dtype: float64

# %%
x['Trades'].head(10)
# Out:
# 0    4320.0
# 1    4320.0
# 2    4320.0
# 3    4320.0
# 4    4320.0
# 5    4320.0
# 6    4320.0
# 7    4320.0
# 8    4320.0
# 9    4320.0
# Name: Trades, dtype: float64

# %%
x['Trades'].tail(10)
# Out:
# 4417     81274.0
# 4418     94720.0
# 4419     69676.0
# 4420     75599.0
# 4421     64854.0
# 4422     74474.0
# 4423    130986.0
# 4424    117843.0
# 4425     64393.0
# 4426     95248.0
# Name: Trades, dtype: float64

# %%
x['Trades'].value_counts()
# Out:
# 4320.0      1970
# 11607.0        2
# 11304.0        2
# 29214.0        2
# 55478.0        2
#             ...
# 50872.0        1
# 122984.0       1
# 67829.0        1
# 11867.0        1
# 179002.0       1
# Name: Trades, Length: 2419, dtype: int64

# %%
x['Trades'].value_counts().max()
# Out:
# 1970

# %% [markdown]
# # To print independent variable

# %%
y=maru["VWAP"]

# %%
y
# Out:
# 0        165.95
# 1        166.74
# 2        172.45
# 3        177.91
# 4        176.88
#          ...
# 4422    6678.34
# 4423    6620.68
# 4424    6598.62
# 4425    6580.77
# 4426    6500.51
# Name: VWAP, Length: 4426, dtype: float64

# %% [markdown]
# # scatter plot of prev close vs year

# %%
plt.scatter(maru['High'],maru['VWAP'])
plt.show()

# %% [markdown]
# ## This scatter plot shows a linear relationship between one independent variable and one             dependent variable

# %% [markdown]
# # Creating training and testing model

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=2)

# %%
x_train
# Out:
#       Prev Close    Open     High      Low     Last    Close   Volume  \
# 338       378.00   389.9   389.90   377.40   379.80   381.30  3423677
# 2137     1193.30  1198.0  1209.90  1167.65  1181.60  1186.70  1045424
# 1447      803.00   779.5   821.80   773.60   813.05   809.35  2957389
# 75        263.80   265.0   291.00   260.00   290.15   285.00  5225375
# 2920     3561.45  3570.0  3619.75  3545.60  3609.15  3610.05   204071
# ...          ...     ...      ...      ...      ...      ...      ...
# 3336     5068.10  5063.9  5219.90  5055.00  5216.10  5202.95   578935
# 1100     1053.80  1048.0  1048.00   995.70  1009.40  1007.00   251000
# 2515     1326.30  1326.0  1359.60  1322.25  1340.00  1340.30   797570
# 3607     9416.60  9450.0  9488.00  9367.20  9393.35  9386.25   562919
# 2576     1636.20  1642.0  1655.85  1626.25  1635.70  1636.15   733492
#
#        Trades  Deliverable Volume      Turnover  %Deliverble
# 338    4320.0            638463.0  1.307540e+14       0.1865
# ...

# %%
len(x_test)
# Out:
# 886

# %%
y_train
# Out:
# 338      381.91
# 2137    1181.44
# 1447     798.56
# 75       275.12
# 2920    3582.22
#          ...
# 3336    5145.06
# 1100    1026.61
# 2515    1341.62
# 3607    9414.19
# 2576    1640.81
# Name: VWAP, Length: 3540, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
d = LinearRegression()

# %%
d.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
d.predict(x_test)
# Out:
# array([ 755.16510516,  806.00345742, 6638.10723757, 1487.44746581,
#        7332.58310764, 1415.73656673,  431.59027878, 5140.72027553,
#        5469.75224262, 4727.70886562,  943.5431257 ,  976.28093912,
#        1205.41301813, 1252.28764294,  418.74692349, 1400.7919044 ,
#         463.55837228, 2610.38716091, 1220.73497265, 3327.38251962,
#         507.62115171, 7326.78712003, 7081.50972801,  193.05414194,
#         343.60524047, 1402.56330957,  790.42292518,  502.84215329,
#        7055.45790649, 7072.42316641, 7184.69589947, 1149.52817649,
#         468.89467685, 6263.76430756, 1405.42144962,  749.16016993,
#         533.53976576, 7181.8611664 ,  805.34172385, 4989.13675897,
#         961.20715742, 8915.94681799,  512.20462298, 1208.36947355,
#        6784.69718118, 1366.29339041, 1420.00649414, 1112.7936359 ,
#        7885.05111384,  773.26739993, 6240.75379743,  961.3186623 ,
#        7099.15745587, 1229.97332099,  996.26401945, 7251.10219945,
# ...

# %%
y_test
# Out:
# 647      754.52
# 1222     807.26
# 3936    6646.86
# 1569    1478.07
# 4367    7315.28
#          ...
# 840      963.50
# 4127    6971.87
# 3705    8603.90
# 1026     825.84
# 2418    1387.73
# Name: VWAP, Length: 886, dtype: float64

# %%
d.score(x_test,y_test)   # Accuracy is 99%
# Out:
# 0.9999774146269199
