# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # Read the data

# %%
lit=pd.read_csv(r"C:\Users\vismaya\Desktop\GOI.csv")

# %% [markdown]
# # view data

# %%
lit
# Out:
#            Category Country/ States/ Union Territories Name  \
# 0           Country                                   INDIA
# 1             State                          Andhra Pradesh
# 2             State                       Arunachal Pradesh
# 3             State                                   Assam
# 4             State                                   Bihar
# 5             State                            Chhattisgarh
# 6             State                                     Goa
# 7             State                                 Gujarat
# 8             State                                 Haryana
# 9             State                        Himachal Pradesh
# 10            State                         Jammu & Kashmir
# 11            State                               Jharkhand
# 12            State                               Karnataka
# 13            State                                  Kerala
# 14            State                          Madhya Pradesh
# ...

# %% [markdown]
# # Rename the columns

# %%
lit.rename(columns={"Literacy Rate (Persons) - Total - 2001":"LR_total_2001","Literacy Rate (Persons) - Total - 2011":"LR_total_2011","Literacy Rate (Persons) - Rural - 2001":"LR_Rural_2001","Literacy Rate (Persons) - Rural - 2011":"LR_Rural_2011","Literacy Rate (Persons) - Urban - 2001":"LR_Urban_2001","Literacy Rate (Persons) - Urban - 2011":"LR-Urban_2011","Country/ States/ Union Territories Name":"Place"},inplace=True)

# %%
lit
# Out:
#            Category              Place  LR_total_2001  LR_total_2011  \
# 0           Country              INDIA           64.8           73.0
# 1             State     Andhra Pradesh           60.5           67.0
# 2             State  Arunachal Pradesh           54.3           65.4
# 3             State              Assam           63.3           72.2
# 4             State              Bihar           47.0           61.8
# 5             State       Chhattisgarh           64.7           70.3
# 6             State                Goa           82.0           88.7
# 7             State            Gujarat           69.1           78.0
# 8             State            Haryana           67.9           75.6
# 9             State   Himachal Pradesh           76.5           82.8
# 10            State    Jammu & Kashmir           55.5           67.2
# 11            State          Jharkhand           53.6           66.4
# 12            State          Karnataka           66.6           75.4
# ...

# %% [markdown]
# # Index of Data Frame

# %%
lit.index
# Out:
# RangeIndex(start=0, stop=36, step=1)

# %% [markdown]
# # To print Top 3 rows

# %%
lit.head(3)
# Out:
#   Category              Place  LR_total_2001  LR_total_2011  LR_Rural_2001  \
# 0  Country              INDIA           64.8           73.0           58.7
# 1    State     Andhra Pradesh           60.5           67.0           54.5
# 2    State  Arunachal Pradesh           54.3           65.4           47.8
#
#    LR_Rural_2011  LR_Urban_2001  LR-Urban_2011
# 0           67.8           79.9           84.1
# 1           60.4           76.1           80.1
# 2           59.9           78.3           82.9

# %% [markdown]
# # To print Bottom 3 rows

# %%
lit.tail(3)
# Out:
#            Category         Place  LR_total_2001  LR_total_2011  \
# 33  Union Territory   Lakshadweep           86.7           91.8
# 34  Union Territory  NCT of Delhi           81.7           86.2
# 35  Union Territory    Puducherry           81.2           85.8
#
#     LR_Rural_2001  LR_Rural_2011  LR_Urban_2001  LR-Urban_2011
# 33           85.0           91.6           88.6           91.9
# 34           78.1           81.9           81.9           86.3
# 35           74.0           80.1           84.8           88.5

# %% [markdown]
# # To check how many rows & columns

# %%
lit.shape
# Out:
# (36, 8)

# %% [markdown]
# # To check the datatype of attributes

# %%
lit.dtypes
# Out:
# Category          object
# Place             object
# LR_total_2001    float64
# LR_total_2011    float64
# LR_Rural_2001    float64
# LR_Rural_2011    float64
# LR_Urban_2001    float64
# LR-Urban_2011    float64
# dtype: object

# %% [markdown]
# # To print no: of dimensions

# %%
lit.ndim
# Out:
# 2

# %% [markdown]
# # To print size of the data

# %%
lit.size
# Out:
# 288

# %% [markdown]
# # To check wheather data type is empty or not

# %%
lit.empty
# Out:
# False

# %% [markdown]
# # Print  the column names

# %%
lit.columns
# Out:
# Index(['Category', 'Place', 'LR_total_2001', 'LR_total_2011', 'LR_Rural_2001',
#        'LR_Rural_2011', 'LR_Urban_2001', 'LR-Urban_2011'],
#       dtype='object')

# %% [markdown]
# # Print the information of dataset

# %%
lit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Category       36 non-null     object
#  1   Place          36 non-null     object
#  2   LR_total_2001  36 non-null     float64
#  3   LR_total_2011  36 non-null     float64
#  4   LR_Rural_2001  36 non-null     float64
#  5   LR_Rural_2011  36 non-null     float64
#  6   LR_Urban_2001  36 non-null     float64
#  7   LR-Urban_2011  36 non-null     float64
# dtypes: float64(6), object(2)
# memory usage: 2.0+ KB

# %% [markdown]
# # Print statistical information

# %%
lit.describe()
# Out:
#        LR_total_2001  LR_total_2011  LR_Rural_2001  LR_Rural_2011  \
# count      36.000000      36.000000      36.000000      36.000000
# mean       69.433333      77.711111      64.669444      73.413889
# std        10.647709       8.497723      11.459440       9.190497
# min        47.000000      61.800000      43.900000      59.800000
# 25%        62.975000      71.725000      57.425000      65.875000
# 50%        68.700000      76.600000      63.300000      71.900000
# 75%        77.225000      85.850000      74.275000      80.875000
# max        90.900000      94.000000      90.000000      93.000000
#
#        LR_Urban_2001  LR-Urban_2011
# count      36.000000      36.000000
# mean       82.161111      86.283333
# std         5.463138       4.982856
# min        69.800000      75.100000
# 25%        79.275000      83.175000
# 50%        81.850000      86.250000
# 75%        84.925000      89.650000
# max        96.100000      97.600000

# %% [markdown]
# # Print all statistical information

# %%
lit.describe(include="all")
# Out:
#        Category       Place  LR_total_2001  LR_total_2011  LR_Rural_2001  \
# count        36          36      36.000000      36.000000      36.000000
# unique        3          36            NaN            NaN            NaN
# top       State  Tamil Nadu            NaN            NaN            NaN
# freq         28           1            NaN            NaN            NaN
# mean        NaN         NaN      69.433333      77.711111      64.669444
# std         NaN         NaN      10.647709       8.497723      11.459440
# min         NaN         NaN      47.000000      61.800000      43.900000
# 25%         NaN         NaN      62.975000      71.725000      57.425000
# 50%         NaN         NaN      68.700000      76.600000      63.300000
# 75%         NaN         NaN      77.225000      85.850000      74.275000
# max         NaN         NaN      90.900000      94.000000      90.000000
#
#         LR_Rural_2011  LR_Urban_2001  LR-Urban_2011
# ...

# %% [markdown]
# # To check is there any missing data

# %%
lit.isna()
# Out:
#     Category  Place  LR_total_2001  LR_total_2011  LR_Rural_2001  \
# 0      False  False          False          False          False
# 1      False  False          False          False          False
# 2      False  False          False          False          False
# 3      False  False          False          False          False
# 4      False  False          False          False          False
# 5      False  False          False          False          False
# 6      False  False          False          False          False
# 7      False  False          False          False          False
# 8      False  False          False          False          False
# 9      False  False          False          False          False
# 10     False  False          False          False          False
# 11     False  False          False          False          False
# 12     False  False          False          False          False
# ...

# %% [markdown]
# # Sum of missing value

# %%
lit.isna().sum()
# Out:
# Category         0
# Place            0
# LR_total_2001    0
# LR_total_2011    0
# LR_Rural_2001    0
# LR_Rural_2011    0
# LR_Urban_2001    0
# LR-Urban_2011    0
# dtype: int64

# %%
lit
# Out:
#            Category              Place  LR_total_2001  LR_total_2011  \
# 0           Country              INDIA           64.8           73.0
# 1             State     Andhra Pradesh           60.5           67.0
# 2             State  Arunachal Pradesh           54.3           65.4
# 3             State              Assam           63.3           72.2
# 4             State              Bihar           47.0           61.8
# 5             State       Chhattisgarh           64.7           70.3
# 6             State                Goa           82.0           88.7
# 7             State            Gujarat           69.1           78.0
# 8             State            Haryana           67.9           75.6
# 9             State   Himachal Pradesh           76.5           82.8
# 10            State    Jammu & Kashmir           55.5           67.2
# 11            State          Jharkhand           53.6           66.4
# 12            State          Karnataka           66.6           75.4
# ...

# %% [markdown]
# # Check the duplicated value

# %%
lit.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# dtype: bool

# %% [markdown]
# # sum of duplicated value

# %%
lit.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Number of unique values in dataset

# %%
lit.nunique()
# Out:
# Category          3
# Place            36
# LR_total_2001    35
# LR_total_2011    36
# LR_Rural_2001    36
# LR_Rural_2011    34
# LR_Urban_2001    32
# LR-Urban_2011    33
# dtype: int64

# %% [markdown]
# # Print unique number in the dataset of Literacy Rate (Persons) - Total - 2001

# %%
lit["LR_total_2001"].unique()
# Out:
# array([64.8, 60.5, 54.3, 63.3, 47. , 64.7, 82. , 69.1, 67.9, 76.5, 55.5,
#        53.6, 66.6, 90.9, 63.7, 76.9, 70.5, 62.6, 88.8, 63.1, 69.7, 60.4,
#        68.8, 73.5, 73.2, 56.3, 71.6, 68.6, 81.3, 81.9, 57.6, 78.2, 86.7,
#        81.7, 81.2])

# %% [markdown]
# # print the count of category in the dataset

# %%
lit["Category"].value_counts()
# Out:
# State              28
# Union Territory     7
# Country             1
# Name: Category, dtype: int64

# %% [markdown]
# # Show the maximum rates

# %%
lit.max()
# Out:
# Category         Union Territory
# Place                West Bengal
# LR_total_2001               90.9
# LR_total_2011               94.0
# LR_Rural_2001               90.0
# LR_Rural_2011               93.0
# LR_Urban_2001               96.1
# LR-Urban_2011               97.6
# dtype: object

# %% [markdown]
# # Show the minimum rates

# %%
lit.min()
# Out:
# Category               Country
# Place            A & N Islands
# LR_total_2001             47.0
# LR_total_2011             61.8
# LR_Rural_2001             43.9
# LR_Rural_2011             59.8
# LR_Urban_2001             69.8
# LR-Urban_2011             75.1
# dtype: object

# %% [markdown]
# # Sort basis of Literacy Rate of Rural in 2011

# %%
lit.sort_values("LR_Rural_2011",ascending=False).head(5)
# Out:
#            Category          Place  LR_total_2001  LR_total_2011  \
# 13            State         Kerala           90.9           94.0
# 33  Union Territory    Lakshadweep           86.7           91.8
# 6             State            Goa           82.0           88.7
# 25            State        Tripura           73.2           87.2
# 29  Union Territory  A & N Islands           81.3           86.6
#
#     LR_Rural_2001  LR_Rural_2011  LR_Urban_2001  LR-Urban_2011
# 13           90.0           93.0           93.2           95.1
# 33           85.0           91.6           88.6           91.9
# 6            79.7           86.6           84.4           90.0
# 25           69.7           84.9           89.2           93.5
# 29           78.7           84.5           86.6           90.1

# %% [markdown]
# # To view the record of KERALA

# %%
lit_Kerala=lit[lit["Place"]=="Kerala"]
lit_Kerala
# Out:
#    Category   Place  LR_total_2001  LR_total_2011  LR_Rural_2001  \
# 13    State  Kerala           90.9           94.0           90.0
#
#     LR_Rural_2011  LR_Urban_2001  LR-Urban_2011
# 13           93.0           93.2           95.1

# %% [markdown]
# # To show maximum no:of Literacy rate in Kerala

# %%
lit_Kerala.sort_values("Place",ascending=False).head(5)
# Out:
#    Category   Place  LR_total_2001  LR_total_2011  LR_Rural_2001  \
# 13    State  Kerala           90.9           94.0           90.0
#
#     LR_Rural_2011  LR_Urban_2001  LR-Urban_2011
# 13           93.0           93.2           95.1

# %%
lit
# Out:
#            Category              Place  LR_total_2001  LR_total_2011  \
# 0           Country              INDIA           64.8           73.0
# 1             State     Andhra Pradesh           60.5           67.0
# 2             State  Arunachal Pradesh           54.3           65.4
# 3             State              Assam           63.3           72.2
# 4             State              Bihar           47.0           61.8
# 5             State       Chhattisgarh           64.7           70.3
# 6             State                Goa           82.0           88.7
# 7             State            Gujarat           69.1           78.0
# 8             State            Haryana           67.9           75.6
# 9             State   Himachal Pradesh           76.5           82.8
# 10            State    Jammu & Kashmir           55.5           67.2
# 11            State          Jharkhand           53.6           66.4
# 12            State          Karnataka           66.6           75.4
# ...

# %% [markdown]
# # specify Category & Place of Literacy Rate in 2011

# %%
rural = lit[["Category", "Place", "LR_Rural_2011"]]
rural
# Out:
#            Category              Place  LR_Rural_2011
# 0           Country              INDIA           67.8
# 1             State     Andhra Pradesh           60.4
# 2             State  Arunachal Pradesh           59.9
# 3             State              Assam           69.3
# 4             State              Bihar           59.8
# 5             State       Chhattisgarh           66.0
# 6             State                Goa           86.6
# 7             State            Gujarat           71.7
# 8             State            Haryana           71.4
# 9             State   Himachal Pradesh           81.9
# 10            State    Jammu & Kashmir           63.2
# 11            State          Jharkhand           61.1
# 12            State          Karnataka           68.7
# 13            State             Kerala           93.0
# 14            State     Madhya Pradesh           63.9
# 15            State        Maharashtra           77.0
# ...

# %% [markdown]
# # To show the last 10 sorted values of the Literacy Rate in 2011

# %%
rural.sort_values("LR_Rural_2011").tail(10)
# Out:
#            Category             Place  LR_Rural_2011
# 30  Union Territory        Chandigarh           80.7
# 32  Union Territory       Daman & Diu           81.4
# 34  Union Territory      NCT of Delhi           81.9
# 9             State  Himachal Pradesh           81.9
# 18            State           Mizoram           84.1
# 29  Union Territory     A & N Islands           84.5
# 25            State           Tripura           84.9
# 6             State               Goa           86.6
# 33  Union Territory       Lakshadweep           91.6
# 13            State            Kerala           93.0

# %% [markdown]
# # grouping total literacy rate in 2001 by category wise

# %%
lit.groupby(['Category']).agg({'LR_total_2001':'sum'})
# Out:
#                  LR_total_2001
# Category
# Country                   64.8
# State                   1886.2
# Union Territory          548.6

# %% [markdown]
# # correlation

# %%
lit.corr()
# Out:
#                LR_total_2001  LR_total_2011  LR_Rural_2001  LR_Rural_2011  \
# LR_total_2001       1.000000       0.952126       0.985199       0.934016
# LR_total_2011       0.952126       1.000000       0.944638       0.971140
# LR_Rural_2001       0.985199       0.944638       1.000000       0.960003
# LR_Rural_2011       0.934016       0.971140       0.960003       1.000000
# LR_Urban_2001       0.760652       0.814676       0.736025       0.770266
# LR-Urban_2011       0.749828       0.839234       0.729318       0.784652
#
#                LR_Urban_2001  LR-Urban_2011
# LR_total_2001       0.760652       0.749828
# LR_total_2011       0.814676       0.839234
# LR_Rural_2001       0.736025       0.729318
# LR_Rural_2011       0.770266       0.784652
# LR_Urban_2001       1.000000       0.981313
# LR-Urban_2011       0.981313       1.000000

# %% [markdown]
# # To print randon data

# %%
lit.sample(5)
# Out:
#            Category        Place  LR_total_2001  LR_total_2011  LR_Rural_2001  \
# 0           Country        INDIA           64.8           73.0           58.7
# 21            State       Punjab           69.7           75.8           64.7
# 27            State  Uttarakhand           71.6           78.8           68.1
# 32  Union Territory  Daman & Diu           78.2           87.1           75.8
# 18            State      Mizoram           88.8           91.3           81.3
#
#     LR_Rural_2011  LR_Urban_2001  LR-Urban_2011
# 0            67.8           79.9           84.1
# 21           71.4           79.1           83.2
# 27           76.3           81.4           84.5
# 32           81.4           82.3           89.0
# 18           84.1           96.1           97.6

# %% [markdown]
# # query to extract state wise data

# %%
lit_state = lit.loc[(lit['Category']=='State')]
lit_state
# Out:
#    Category              Place  LR_total_2001  LR_total_2011  LR_Rural_2001  \
# 1     State     Andhra Pradesh           60.5           67.0           54.5
# 2     State  Arunachal Pradesh           54.3           65.4           47.8
# 3     State              Assam           63.3           72.2           59.7
# 4     State              Bihar           47.0           61.8           43.9
# 5     State       Chhattisgarh           64.7           70.3           60.5
# 6     State                Goa           82.0           88.7           79.7
# 7     State            Gujarat           69.1           78.0           61.3
# 8     State            Haryana           67.9           75.6           63.2
# 9     State   Himachal Pradesh           76.5           82.8           75.1
# 10    State    Jammu & Kashmir           55.5           67.2           49.8
# 11    State          Jharkhand           53.6           66.4           45.7
# ...

# %% [markdown]
# # query to extract the data of Union Territory

# %%
lit_union = lit.loc[(lit['Category']=='Union Territory')]
lit_union
# Out:
#            Category          Place  LR_total_2001  LR_total_2011  \
# 29  Union Territory  A & N Islands           81.3           86.6
# 30  Union Territory     Chandigarh           81.9           86.0
# 31  Union Territory   D & N Haveli           57.6           76.2
# 32  Union Territory    Daman & Diu           78.2           87.1
# 33  Union Territory    Lakshadweep           86.7           91.8
# 34  Union Territory   NCT of Delhi           81.7           86.2
# 35  Union Territory     Puducherry           81.2           85.8
#
#     LR_Rural_2001  LR_Rural_2011  LR_Urban_2001  LR-Urban_2011
# 29           78.7           84.5           86.6           90.1
# 30           75.6           80.7           82.6           86.2
# 31           49.3           64.1           84.4           89.8
# 32           75.8           81.4           82.3           89.0
# 33           85.0           91.6           88.6           91.9
# 34           78.1           81.9           81.9           86.3
# ...

# %% [markdown]
# # Higher literacy rate across union territory-2011

# %%
union_2011 = lit_union[['Place', 'LR_total_2011', 'LR_Rural_2011', 'LR-Urban_2011']]
union_2011
# Out:
#             Place  LR_total_2011  LR_Rural_2011  LR-Urban_2011
# 29  A & N Islands           86.6           84.5           90.1
# 30     Chandigarh           86.0           80.7           86.2
# 31   D & N Haveli           76.2           64.1           89.8
# 32    Daman & Diu           87.1           81.4           89.0
# 33    Lakshadweep           91.8           91.6           91.9
# 34   NCT of Delhi           86.2           81.9           86.3
# 35     Puducherry           85.8           80.1           88.5

# %% [markdown]
# # Seaborn

# %% [markdown]
# # line plot of total literacy rate in 2001 & 2011

# %% [markdown]
# ##   A line can be defined as a graph that displays data as points or check marks above a                number line, showing the frequency of each value

# %%
sns.lineplot(x="LR_total_2011", y="LR_total_2001", hue="Category", data=lit)
plt.show()

# %% [markdown]
# # Strip plot  of literacy rate of rural 2001 & category

# %% [markdown]
# ##  In strip plot we try to visualize the rural literacy rate in 2011 with the category.

# %%
sns.set_style("darkgrid")
sns.stripplot(x="LR_Rural_2011", y="Category", data=lit)
plt.show()

# %% [markdown]
# # Literacy Rate of Rural 2001 & Category using  jitter

# %% [markdown]
# ##  jitter can be used to provide displacements along the horizontal axis
#
# conclusion : it is very useful when there are large clusters of data points.

# %%
sns.set_style("darkgrid")
sns.stripplot(x="Category",y="LR_Rural_2011",jitter=0.20,data=lit)
plt.show()

# %% [markdown]
# # Scatter plot of rural literacy rate in 2001 & 2011

# %% [markdown]
# ##   A scatter plot uses dots to represent values for two different numeric variables.The                    position  of each dot on the horizontal and vertical axis indicates values for an individual         data point.Scatter plots are used to observe relationships between variables
#
# conclusion : it shows the relationship between rural literacy rate in 2001 and 2011

# %%
sns.scatterplot(x="LR_Rural_2001", y="LR_Rural_2011", data=lit)
plt.show()

# %% [markdown]
# # rel plot of literacy rate of rural 2001 & 2011

# %% [markdown]
# ##  rel plot is a figure-level function for visulazing statistical relationship using two common         approaches

# %%
sns.relplot(x='LR_Rural_2001', y="LR_Rural_2011", data=lit)
plt.show()

# %% [markdown]
# # Total literacy rate of 2001 using  kdeplot

# %% [markdown]
# ##  It shows the relationship between density and total literacy rate in 2001 by in a curved plot

# %%
sns.kdeplot(lit["LR_total_2001"])
plt.show()

# %% [markdown]
# # using color

# %%
sns.kdeplot(lit["LR_total_2001"], color="blue", shade=True)
plt.show()

# %% [markdown]
# # vertical kdeplot

# %%
sns.kdeplot(lit["LR_total_2001"], color="blue", vertical=True, shade=True)
plt.show()

# %% [markdown]
# # Total literacy rate of 2001 Vs 2011 using green color

# %%
sns.kdeplot(lit["LR_total_2001"], lit["LR_total_2011"], color="green", shade=True)
plt.show()

# %% [markdown]
# # pairplot of Literacy Rate in lndia

# %% [markdown]
# ##  A pairplot plot a pairwise relationships in a dataset. The pairplot function creates a grid of Axes such that each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column

# %%
sns.pairplot(lit)
plt.show()

# %% [markdown]
# # pair plot using curved format

# %%
sns.pairplot(lit,diag_kind="kde")
plt.show()

# %% [markdown]
# # using histogram & region

# %%
sns.pairplot(lit,diag_kind="hist", kind="reg")
plt.show()

# %% [markdown]
# # violin plot category  vs total literacy rate of 2001

# %% [markdown]
# ##   It shows the distribution of quantitative data across several levels of one (or more)                     categorical variables such that those distribution can be compared
#
# conclusion : it shows the category like violin shape

# %%
sns.violinplot(x="Category", y="LR_total_2001", hue="Category", figsize=33, data=lit)
plt.show()

# %% [markdown]
# # swarm plot of Category

# %% [markdown]
# ##  it is a categorical scatterplot with non-overlapping points

# %%
sns.swarmplot(lit["Category"])
plt.show()

# %% [markdown]
# # Swarm plot between Category & Total literacy rate of 2001

# %%
sns.swarmplot(x="Category",y="LR_total_2001",data=lit)
plt.show()

# %% [markdown]
# # using hue
#
# which shows the details of category on left side

# %%
sns.swarmplot(x="Category",y="LR_total_2001",hue="Category",data=lit)
plt.show()

# %% [markdown]
# # Box Plot of  literacy rate of rural in 2001

# %% [markdown]
# ##  it shows that the given data is symmetrical, how the data is grouped, and if and how your         data is skewed.
#
# conclusion : the rural literacy rate in 2001 is grouped in tightly

# %%
sns.boxplot(lit['LR_Rural_2001'])
plt.show()

# %% [markdown]
# # vertical box plot

# %%
sns.boxplot(y=lit["LR_Rural_2001"])
plt.show()

# %% [markdown]
# # Heat Map

# %% [markdown]
# ## correlation

# %%
lit.corr()
# Out:
#                LR_total_2001  LR_total_2011  LR_Rural_2001  LR_Rural_2011  \
# LR_total_2001       1.000000       0.952126       0.985199       0.934016
# LR_total_2011       0.952126       1.000000       0.944638       0.971140
# LR_Rural_2001       0.985199       0.944638       1.000000       0.960003
# LR_Rural_2011       0.934016       0.971140       0.960003       1.000000
# LR_Urban_2001       0.760652       0.814676       0.736025       0.770266
# LR-Urban_2011       0.749828       0.839234       0.729318       0.784652
#
#                LR_Urban_2001  LR-Urban_2011
# LR_total_2001       0.760652       0.749828
# LR_total_2011       0.814676       0.839234
# LR_Rural_2001       0.736025       0.729318
# LR_Rural_2011       0.770266       0.784652
# LR_Urban_2001       1.000000       0.981313
# LR-Urban_2011       0.981313       1.000000

# %% [markdown]
# # correlation of literacy rate in lndia using heatmap

# %% [markdown]
# ##  A heatmap is a graphical representation of data that uses a system of color-coding to               represent  the  values.

# %%
sns.heatmap(lit.corr())
plt.show()

# %% [markdown]
# # using annotation

# %%
sns.heatmap(lit.corr(), cmap='RdBu',annot=True)
plt.show()

# %% [markdown]
# # using format
#
# cmap is shows the red blue color and format is shows the 0.1 wise values

# %%
sns.heatmap(lit.corr(), cmap='RdBu',annot=True, fmt='.1f')
plt.show()

# %% [markdown]
# # Distplot of Total literacy rate in 2011

# %% [markdown]
# ##  in this distplot we visualize the total literacy rate in 2011 against the density distribution

# %%
sns.distplot(lit.LR_total_2011)
plt.show()

# %% [markdown]
# # Displot of Total literacy rate in 2011

# %% [markdown]
# ##  displot is only show the bar graph

# %%
sns.displot(lit.LR_total_2011)
plt.show()

# %% [markdown]
# # usinf red color

# %%
sns.distplot(lit.LR_total_2011, color='red')
plt.show()

# %% [markdown]
# # without bar graph using distplot

# %%
sns.distplot(lit.LR_total_2011, hist=False)
plt.show()

# %% [markdown]
# # without kde

# %%
sns.distplot(lit.LR_total_2011, kde=False)
plt.show()

# %% [markdown]
# # Distplot of total literacy rate-2011

# %%
plt.figure(figsize=(8,5))
sns.distplot(lit.LR_total_2011,
             bins=20,
             kde_kws={'lw':8, 'color':'xkcd:bluish green'},
             hist_kws={'alpha':0.3, 'color':'gray'}
            )
plt.xlabel('LR_total_2011', fontsize=16, labelpad=15)
plt.yticks([])
plt.show()

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Pie Chart of Literacy Rate in lndia
#
# conclusion : all deatils showing in a various colors

# %%
y = np.array([0,20,40,60,80,100])
l= ["LR_total-2001", "LR_total_2011", "LR-Rural-2001", "LR_Rural-2011", "LR_Urban_2001", "LR_Urban_2011"]
c = ['r', 'b', 'g', 'k']

plt.pie(y,labels=l, startangle=90, shadow=True, colors=c, explode=(0,0.5,0,0,0,0))
plt.legend(loc='lower right', title='Literacy rate across State')
plt.show()

# %% [markdown]
# # Literacy rate total in 2001  Vs  Literacy rate total in 2011

# %% [markdown]
# ##  it shows the highest and lowest  literacy rate in india is

# %%
plt.figure(figsize=(10,5))
plt.bar(lit["LR_Rural_2011"],lit["LR_total_2001"])
plt.title("LR_Rural_2011 Vs LR_total_2001",fontsize=2,color="red")
plt.xlabel("LR_Rural_2011",fontsize=15)
plt.ylabel("LR_total_2001",fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# # rel plot of literacy rate of rural in 2011 Vs Total literacy rate in 2001

# %% [markdown]
# #  rel plot is a figure-level function for visualizing statistical relationship using      two common approaches.
#
# conclusion : it combines a FaceGrid with total literacy rate in 2001 & rural literacy rate in 2011

# %%
plt.figure(figsize=(16,18))
sns.relplot(x='LR_Rural_2011', y='LR_total_2001', data=lit)
plt.show()

# %% [markdown]
# # Category using count plot & set of colors ( palette)

# %%
sns.countplot(y='Category', data=lit, palette='tab10')
plt.show()

# %% [markdown]
# # Pie chart of Category
#
# ln this piechart we try to visualize counts of category

# %%
plt.title('Category', fontsize=20)
lit['Category'].value_counts().plot.pie(autopct='%1.1f%%, shadow=True')
plt.show()

# %% [markdown]
# # Literacy rate of urban areas in the year 2001 & 2011

# %% [markdown]
# ##   we can easly vizualize the literacy rate of urban in 2001 & 2011. red color shows urban lr           of 2001  and yellow color shows the urban lr of 2011

# %%
lit.groupby('Category')[['LR_Urban_2001','LR-Urban_2011']].sum().plot.bar(color=['red','yellow'], figsize=(8,5))
plt.ylabel('LR_Urban_2001/LR-Urban_2011')
plt.show()

# %% [markdown]
# # Category using count plot

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Category', data=lit, palette='rocket_r',order=lit['Category'].value_counts().index)
plt.xlabel('Category', fontsize=25)
plt.xticks(rotation=70)
plt.show()
